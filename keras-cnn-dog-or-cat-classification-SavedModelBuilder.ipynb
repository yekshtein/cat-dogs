# %% [markdown]
# # Import Library

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random

import os
location = "/User/.keras/datasets/cats_and_dogs_filtered/"
print(os.listdir(location))

FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3 # RGB color

# Any results you write to the current directory are saved as output.
# Out:
# ['cats_n_dogs', 'train', 'validation', 'vectorize.py']

# %% [markdown]
# # Prepare Traning Data

# %%
filenames = os.listdir(location+"/cats_n_dogs")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})
df['category'] = df['category'].astype('str');

# %%
df.head()
# Out:
#       filename category
# 0    cat.0.jpg        0
# 1    cat.1.jpg        0
# 2   cat.10.jpg        0
# 3  cat.100.jpg        0
# 4  cat.101.jpg        0

# %%
df.tail()
# Out:
#          filename category
# 1995  dog.995.jpg        1
# 1996  dog.996.jpg        1
# 1997  dog.997.jpg        1
# 1998  dog.998.jpg        1
# 1999  dog.999.jpg        1

# %% [markdown]
# ### See Total In count

# %%
df['category'].value_counts().plot.bar()

# %% [markdown]
# From our data we have 12000 cats and 12000 dogs

# %% [markdown]
# # See sample image

# %%
sample = random.choice(filenames)
image = load_img(location+"/cats_n_dogs/"+sample)
plt.imshow(image)

# %% [markdown]
# # Build Model
#
# <img src="https://i.imgur.com/ebkMGGu.jpg" width="100%"/>

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 12,942,273
# Trainable params: 12,940,801
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# # Callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# **Early Stop**
#
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# **Learning Rate Reduction**
#
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# ### Prepare Test and Train Data

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'] = train_df['category'].astype('str');
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %% [markdown]
# # Traning Generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    location + "/cats_n_dogs/", 
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'binary',
    batch_size = batch_size
)
# Out:
# Found 1600 images belonging to 2 classes.

# %% [markdown]
# ### Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    location + "/cats_n_dogs/", 
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'binary',
    batch_size = batch_size
)
# Out:
# Found 400 images belonging to 2 classes.

# %% [markdown]
# # See how our generator work

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)

example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    location + "/cats_n_dogs/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='binary'
)

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# Seem to be nice

# %% [markdown]
# # Fit Model

# %%
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From /User/.pythonlibs/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 106/106 [==============================] - 47s 446ms/step - loss: 1.1221 - acc: 0.5616 - val_loss: 1.3604 - val_acc: 0.5308
# Epoch 2/50
# 106/106 [==============================] - 44s 414ms/step - loss: 0.8839 - acc: 0.5997 - val_loss: 1.1164 - val_acc: 0.5740
# Epoch 3/50
# 106/106 [==============================] - 44s 415ms/step - loss: 0.7698 - acc: 0.6028 - val_loss: 0.7728 - val_acc: 0.6104
# Epoch 4/50
# 106/106 [==============================] - 44s 415ms/step - loss: 0.7058 - acc: 0.6522 - val_loss: 0.7384 - val_acc: 0.6364
# Epoch 5/50
# 106/106 [==============================] - 44s 415ms/step - loss: 0.6782 - acc: 0.6481 - val_loss: 0.8280 - val_acc: 0.6052
# Epoch 6/50
# 106/106 [==============================] - 44s 417ms/step - loss: 0.6408 - acc: 0.6711 - val_loss: 0.5874 - val_acc: 0.7013
# Epoch 7/50
# 106/106 [==============================] - 44s 414ms/step - loss: 0.6047 - acc: 0.6899 - val_loss: 0.6163 - val_acc: 0.7065
# Epoch 8/50
# 106/106 [==============================] - 44s 415ms/step - loss: 0.5926 - acc: 0.6862 - val_loss: 0.6368 - val_acc: 0.6961
# Epoch 9/50
# 106/106 [==============================] - 44s 420ms/step - loss: 0.5660 - acc: 0.7160 - val_loss: 0.6114 - val_acc: 0.7013
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/50
# 106/106 [==============================] - 44s 416ms/step - loss: 0.5243 - acc: 0.7431 - val_loss: 0.5391 - val_acc: 0.7584
# Epoch 11/50
# 106/106 [==============================] - 44s 419ms/step - loss: 0.5202 - acc: 0.7352 - val_loss: 0.5593 - val_acc: 0.7455
# Epoch 12/50
# 106/106 [==============================] - 45s 420ms/step - loss: 0.5049 - acc: 0.7522 - val_loss: 0.5276 - val_acc: 0.7532
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/50
# 106/106 [==============================] - 44s 417ms/step - loss: 0.4715 - acc: 0.7764 - val_loss: 0.5434 - val_acc: 0.7532
# Epoch 14/50
# 106/106 [==============================] - 44s 416ms/step - loss: 0.4699 - acc: 0.7670 - val_loss: 0.5567 - val_acc: 0.7532
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/50
# 106/106 [==============================] - 44s 416ms/step - loss: 0.4434 - acc: 0.7887 - val_loss: 0.5632 - val_acc: 0.7740
# Epoch 16/50
# 106/106 [==============================] - 44s 415ms/step - loss: 0.4578 - acc: 0.7789 - val_loss: 0.5238 - val_acc: 0.7818
# Epoch 17/50
# 106/106 [==============================] - 44s 416ms/step - loss: 0.4302 - acc: 0.7994 - val_loss: 0.5926 - val_acc: 0.7377
# Epoch 18/50
# 106/106 [==============================] - 45s 420ms/step - loss: 0.4350 - acc: 0.7981 - val_loss: 0.5610 - val_acc: 0.7792
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 19/50
# 106/106 [==============================] - 44s 416ms/step - loss: 0.4170 - acc: 0.8013 - val_loss: 0.6008 - val_acc: 0.7714
# Epoch 20/50
# 106/106 [==============================] - 44s 418ms/step - loss: 0.4306 - acc: 0.7890 - val_loss: 0.5714 - val_acc: 0.7740
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 21/50
# 106/106 [==============================] - 44s 416ms/step - loss: 0.4231 - acc: 0.8044 - val_loss: 0.6188 - val_acc: 0.7662
# Epoch 22/50
# 106/106 [==============================] - 44s 418ms/step - loss: 0.4318 - acc: 0.8013 - val_loss: 0.5413 - val_acc: 0.7766
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 23/50
# 106/106 [==============================] - 44s 416ms/step - loss: 0.4249 - acc: 0.7924 - val_loss: 0.6103 - val_acc: 0.7792
# Epoch 24/50
# 106/106 [==============================] - 44s 414ms/step - loss: 0.4332 - acc: 0.7940 - val_loss: 0.5364 - val_acc: 0.7948
# Epoch 25/50
# 106/106 [==============================] - 44s 415ms/step - loss: 0.4444 - acc: 0.7937 - val_loss: 0.5978 - val_acc: 0.7688
# Epoch 26/50
# 106/106 [==============================] - 44s 416ms/step - loss: 0.4192 - acc: 0.8016 - val_loss: 0.5535 - val_acc: 0.7896
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1e-05.

# %% [markdown]
# # Save Model

# %%
model.save_weights("model.h5")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-17c8c31f4020> in <module>
# ----> 1 model.fit(train_datagen, train_generator, epochs=3)
#
# /conda/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# /conda/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# /conda/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#      90         data = data.values if data.__class__.__name__ == 'DataFrame' else data
#      91         data = [data]
# ---> 92     data = [standardize_single_array(x) for x in data]
#      93
#      94     if len(data) != len(names):
#
# /conda/lib/python3.6/site-packages/keras/engine/training_utils.py in <listcomp>(.0)
#      90         data = data.values if data.__class__.__name__ == 'DataFrame' else data
#      91         data = [data]
# ---> 92     data = [standardize_single_array(x) for x in data]
#      93
#      94     if len(data) != len(names):
#
# /conda/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_single_array(x)
#      25                 'Got tensor with shape: %s' % str(shape))
#      26         return x
# ---> 27     elif x.ndim == 1:
#      28         x = np.expand_dims(x, 1)
#      29     return x
#
# AttributeError: 'ImageDataGenerator' object has no attribute 'ndim'

# %% [markdown]
# # Visualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['acc'], color='b', label="Training accuracy")
ax2.plot(history.history['val_acc'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Prepare Testing Data

# %%
test_filenames = os.listdir(location + "/validation/")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %% [markdown]
# # Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    location + "/validation/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 1000 images.

# %% [markdown]
# # Predict

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
#print (predict)

# %% [markdown]
# As predicted of binary classification result return probability that image likely to be a dog. So we will have threshold 0.5 which mean if predicted value more than 50% it is a dog and under 50% will be a cat.

# %%
threshold = 0.5
test_df['probability'] = predict
test_df['category'] = np.where(test_df['probability'] > threshold, 1,0)

# %% [markdown]
# ### Virtaulize Result

# %%
test_df['category'].value_counts().plot.bar()

# %% [markdown]
# ### See predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    probability = row['probability']
    img = load_img(location + "/validation/"+filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' '(' + "{}".format(round(probability, 2)) + ')')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Submission

# %%
submission_df = test_df.copy()
submission_df['id'] = submission_df['filename'].str.split('.').str[0]
submission_df['label'] = submission_df['category']
submission_df.drop(['filename', 'category'], axis=1, inplace=True)
submission_df.to_csv('submission.csv', index=False)
